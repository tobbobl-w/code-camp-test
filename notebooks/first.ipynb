# %%
# %load_ext autoreload
# %autoreload 2

import camp
import numpy as np

# %%
camp.utils.hello(0.0)

try :
    camp.utils.compute_mean([0.0, 1.0, 2.0, 3.0])
    print(f"Caught an assertion error: {e}")
except Exception as e:
    print(f"Caught an unexpected error: {e}")
# Out:
# Hello again one more time, 0.0!
# Caught an unexpected error: All numbers must be non-zero.

# %%
print("Hello, Economics Code Camp!")
print(f"I'm running Python in a container!")

# Let's do some basic math
gdp_2020 = 21_427_700  # US GDP in millions of dollars
gdp_2021 = 23_315_080
growth_rate = (gdp_2021 - gdp_2020) / gdp_2020 * 100

print(f"US GDP growth rate 2020-2021: {growth_rate:.2f}%")
# Out:
# Hello, Economics Code Camp!
# I'm running Python in a container!
# US GDP growth rate 2020-2021: 8.81%

# %%
np.random.seed(0)
n = 1000
x = np.random.normal(0, 1, n)
camp.utils.compute_statistics(x)
# Out:
# {'variance': np.float64(0.9752096659781323),
#  'skewness': np.float64(0.03385895323565712),
#  'kurtosis': np.float64(-0.0467663244783294)}

# %%
import pyreadstat

# Replace with the path to your .dta file
df, meta = pyreadstat.read_dta("../data/bpp.dta")

print(df.head())       # Pandas DataFrame with your data
print(meta.column_names)  # Metadata about columns
print(meta.file_label)    # Stata file label, if any
# Out:
#    person  seo    year  id  pid    house   rent   util    food  fstmp  ...  \
# 0       1    0  1967.0   1    1  15000.0    0.0  250.0  2106.0    0.0  ...
# 1   11397    1  1968.0   1    1      0.0  840.0  150.0  2080.0    0.0  ...
# 2    1577    0  1969.0   1    1  12000.0    0.0  350.0  1796.0    0.0  ...
# 3    4359    0  1970.0   1    1  27000.0    0.0  250.0  1300.0    0.0  ...
# 4    1194    0  1971.0   1    1      0.0  960.0  350.0  1560.0    0.0  ...
#
#     fout  asset  trhf  hhelp  ohelp  unionj  unioni  truncy trunca whelp
# 0    NaN    NaN   NaN    NaN    NaN     NaN     NaN     NaN    NaN   NaN
# 1  260.0    NaN   NaN    NaN    NaN     NaN     NaN     NaN    NaN   NaN
# 2    0.0    NaN   NaN    NaN    NaN     NaN     NaN     NaN    NaN   NaN
# 3  390.0    NaN   NaN    NaN    NaN     NaN     NaN     NaN    NaN   NaN
# 4  104.0    NaN   NaN    NaN    NaN     NaN     NaN     NaN    NaN   NaN
#
# [5 rows x 52 columns]
# ['person', 'seo', 'year', 'id', 'pid', 'house', 'rent', 'util', 'food', 'fstmp', 'hours', 'hourw', 'ly', 'wly', 'tyhw', 'tyoth', 'y', 'ftax', 'state', 'smsa', 'fsize', 'age', 'agew', 'sex', 'ncars', 'race', 'empst', 'self', 'marit', 'wages', 'educ', 'vet', 'avhy', 'kids', 'weight', 'disab', 'outkid', 'troth', 'trhw', 'split', 'fchg', 'newhd', 'fout', 'asset', 'trhf', 'hhelp', 'ohelp', 'unionj', 'unioni', 'truncy', 'trunca', 'whelp']
# None

# %%
import numpy as np
import matplotlib.pyplot as plt
ly = [ np.log(y) for y in df.y if y > 0 ]
plt.hist(ly, bins=30)
print(np.var(ly))
# Out:
# 1.3820948914353275

# %%
np.var(df['ly'])
# Out:
# np.float64(332436883.45378923)

# %%
df.sort_values(['person', 'year'])
# Out:
#         person  seo    year    id  pid    house    rent   util    food  \
# 0            1    0  1967.0     1    1  15000.0     0.0  250.0  2106.0
# 40729        1    0  1968.0  1597    1  15000.0     0.0  350.0   988.0
# 33939        2    0  1969.0  1331    1  20000.0     0.0  350.0   780.0
# 2713         2    0  1970.0   108    1  16000.0     0.0  350.0   780.0
# 1131         2    0  1971.0    45    1  16000.0     0.0  385.0   520.0
# ...        ...  ...     ...   ...  ...      ...     ...    ...     ...
# 146020   18532    1  1988.0  6088    1      0.0     NaN    NaN     NaN
# 40674    18532    1  1989.0  1594    1      0.0  3720.0    NaN  3120.0
# 110060   18532    1  1990.0  4356    1      0.0  3900.0    NaN  3640.0
# 162198   18532    1  1991.0  8874    1      0.0  6600.0    NaN   720.0
# 31025    18532    1  1992.0  1217    1      0.0  6600.0    NaN  3120.0
#
#          fstmp  ...    fout  asset  trhf  hhelp  ohelp  unionj  unioni  \
# 0          0.0  ...     NaN    NaN   NaN    NaN    NaN     NaN     NaN
# 40729      0.0  ...     0.0    NaN   NaN    NaN    NaN     NaN     NaN
# 33939      0.0  ...     0.0    NaN   NaN    NaN    NaN     NaN     NaN
# 2713       0.0  ...     0.0    NaN   NaN    NaN    NaN     NaN     NaN
# 1131       0.0  ...    52.0    NaN   NaN    NaN    NaN     NaN     NaN
# ...        ...  ...     ...    ...   ...    ...    ...     ...     ...
# 146020     0.0  ...     NaN    0.0   NaN    0.0      0       1       1
# 40674   2000.0  ...  2080.0    0.0   NaN    0.0      0       1       1
# 110060     0.0  ...  1040.0    0.0   NaN    0.0      0       1       1
# 162198  3600.0  ...   480.0    0.0   NaN    0.0      0       1       1
# 31025      0.0  ...   420.0    0.0   NaN    0.0      0       1       1
#
#         truncy trunca whelp
# 0          NaN    NaN   NaN
# 40729      NaN    NaN   NaN
# 33939      NaN    NaN   NaN
# 2713       NaN    NaN   NaN
# 1131       NaN    NaN   NaN
# ...        ...    ...   ...
# 146020     0.0    0.0   0.0
# 40674      0.0    0.0   0.0
# 110060     0.0    0.0   0.0
# 162198     0.0    0.0   0.0
# 31025      0.0    0.0   0.0
#
# [163871 rows x 52 columns]

# %%
id_col = "person"

# 1. Sort by person and year
df = df.sort_values([id_col, "year"])
df["ly"] = np.log(df["y"])
df = df.dropna(subset=["ly"])

# 2. Compute growth (first difference of y within person)
df["dy"] = df.groupby(id_col)["ly"].diff()

# 3. Pivot so that rows = person, columns = year, values = dy
dy_wide = df.pivot(index=id_col, columns="year", values="dy")

# 4. Compute variance-covariance matrix across years
# pandas .cov() will automatically handle missing values pairwise
cov_matrix = dy_wide.cov()

print(cov_matrix)
# Out:
# /home/vscode/.local/lib/python3.11/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# year    1967.0    1968.0    1969.0    1970.0    1971.0    1972.0    1973.0  \
# year
# 1967.0     NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1968.0     NaN  0.177835 -0.043361 -0.011439 -0.007849  0.007535 -0.002802
# 1969.0     NaN -0.043361  0.230140 -0.125242 -0.008672  0.000169 -0.005326
# 1970.0     NaN -0.011439 -0.125242  0.247367 -0.050858 -0.008585 -0.002240
# 1971.0     NaN -0.007849 -0.008672 -0.050858  0.248566 -0.098008 -0.004434
# 1972.0     NaN  0.007535  0.000169 -0.008585 -0.098008  0.292037 -0.095328
# 1973.0     NaN -0.002802 -0.005326 -0.002240 -0.004434 -0.095328  0.254105
# 1974.0     NaN -0.016364 -0.006117  0.005184  0.015147 -0.022025 -0.078499
# 1975.0     NaN  0.020901  0.021790 -0.022756 -0.029700  0.007257 -0.020141
# person
# 2            NaN  0.119861 -0.011653  0.298562 -0.113282  0.277937       NaN
# 3       0.149218  0.131006  0.278392 -0.116534  0.298855  0.098713  0.092595
# 5            NaN  0.926762 -0.337514  0.047515  0.069457 -0.060219       NaN
# 8       0.633754 -0.518578  0.417214  0.545297  0.042223 -0.902779 -9.811372
# 9            NaN       NaN       NaN  0.497403  0.258198  0.403096 -0.009814
# ...          ...       ...       ...       ...       ...       ...       ...
# 18525        NaN       NaN       NaN       NaN       NaN       NaN  0.491677
# 18527   0.181492 -0.030010       NaN       NaN  0.458040       NaN       NaN
# 18530   0.009217  0.332533 -0.615699  0.091628  0.406206       NaN -0.498321
# 18531        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 18532        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# year      1978.0    1979.0    1980.0  ...    1983.0    1984.0    1985.0  \
# person                                ...
# 2            NaN       NaN       NaN  ...       NaN       NaN       NaN
# 3       0.127145       NaN       NaN  ...       NaN       NaN       NaN
# 5            NaN       NaN  1.107955  ...  0.351454 -0.779198  0.860378
# 8       9.681219  1.609038 -1.051155  ...  0.394145 -0.216505  0.239728
# 9       0.242952  0.146227  0.039771  ...  0.087153  0.172667 -0.145403
# ...          ...       ...       ...  ...       ...       ...       ...
# 18525   0.150874 -0.121509  0.315288  ...  0.218482 -0.047856 -0.151005
# 18527        NaN       NaN       NaN  ...       NaN       NaN       NaN
# 18530   0.084083  0.485783  0.504327  ...  0.569892  0.109519 -0.006940
# 18531        NaN       NaN       NaN  ... -0.370663       NaN  1.008335
# 18532        NaN       NaN       NaN  ...       NaN       NaN       NaN
#
# year      1986.0    1987.0    1988.0    1989.0    1990.0    1991.0    1992.0
# person
# 2            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5            NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8      -0.400676  0.058990  0.121951 -0.686766  0.400431  0.215533 -0.859548
# 9       0.158931  0.030717 -0.003600 -0.181939  0.192887  0.333912 -0.257149
# ...          ...       ...       ...       ...       ...       ...       ...
# 18525   0.243245 -0.002291  0.126111  0.010998 -0.031749  0.306298 -0.170753
# 18527        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 18530   0.049089 -0.410950  0.705570  0.320472 -0.438255  0.154389 -1.919831
# 18531   0.075753  0.048771 -0.039144  0.098752  0.091522       NaN  0.160453
# 18532        NaN       NaN       NaN  0.547295  0.279383       NaN  0.318454
#
# [11014 rows x 22 columns]

# %%
df
# Out:
#         person  seo    year    id  pid    house    rent   util    food  \
# 40729        1    0  1968.0  1597    1  15000.0     0.0  350.0   988.0
# 2713         2    0  1970.0   108    1  16000.0     0.0  350.0   780.0
# 1131         2    0  1971.0    45    1  16000.0     0.0  385.0   520.0
# 2045         2    0  1972.0    81    1  16000.0     0.0    NaN     NaN
# 9560         2    0  1973.0   378    1  20000.0     0.0    NaN  1040.0
# ...        ...  ...     ...   ...  ...      ...     ...    ...     ...
# 146020   18532    1  1988.0  6088    1      0.0     NaN    NaN     NaN
# 40674    18532    1  1989.0  1594    1      0.0  3720.0    NaN  3120.0
# 110060   18532    1  1990.0  4356    1      0.0  3900.0    NaN  3640.0
# 162198   18532    1  1991.0  8874    1      0.0  6600.0    NaN   720.0
# 31025    18532    1  1992.0  1217    1      0.0  6600.0    NaN  3120.0
#
#          fstmp  ...  asset  trhf  hhelp  ohelp  unionj  unioni  truncy  \
# 40729      0.0  ...    NaN   NaN    NaN    NaN     NaN     NaN     NaN
# 2713       0.0  ...    NaN   NaN    NaN    NaN     NaN     NaN     NaN
# 1131       0.0  ...    NaN   NaN    NaN    NaN     NaN     NaN     NaN
# 2045       NaN  ...    NaN   NaN    NaN    NaN     NaN     NaN     NaN
# 9560       0.0  ...    NaN   NaN    NaN    NaN     NaN     NaN     NaN
# ...        ...  ...    ...   ...    ...    ...     ...     ...     ...
# 146020     0.0  ...    0.0   NaN    0.0      0       1       1     0.0
# 40674   2000.0  ...    0.0   NaN    0.0      0       1       1     0.0
# 110060     0.0  ...    0.0   NaN    0.0      0       1       1     0.0
# 162198  3600.0  ...    0.0   NaN    0.0      0       1       1     0.0
# 31025      0.0  ...    0.0   NaN    0.0      0       1       1     0.0
#
#         trunca whelp        dy
# 40729      NaN   NaN -0.731563
# 2713       NaN   NaN -0.106136
# 1131       NaN   NaN -0.140500
# 2045       NaN   NaN  0.119861
# 9560       NaN   NaN -0.011653
# ...        ...   ...       ...
# 146020     0.0   0.0  0.712039
# 40674      0.0   0.0  0.547295
# 110060     0.0   0.0  0.279383
# 162198     0.0   0.0  0.000000
# 31025      0.0   0.0  0.318454
#
# [147842 rows x 53 columns]

# %%
id_col = "person"
df = camp.utils.simulate_panel_ar1(800, 6, 0.90, 0.2, 1.2)

# 2. Compute growth (first difference of y within person)
df["dy"] = df.groupby(id_col)["y"].diff()

# 3. Pivot so that rows = person, columns = year, values = dy
dy_wide = df.pivot(index=id_col, columns="year", values="dy")

# 4. Compute variance-covariance matrix across years
# pandas .cov() will automatically handle missing values pairwise
cov_matrix = dy_wide.cov()

print(cov_matrix)

results = camp.utils.estimate_panel_ar1_statsmodels(df)
print(results.summary())
# Out:
# year   0         1         2         3         4         5         6  \
# year
# 0    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1    NaN  0.211663 -0.007098 -0.010160 -0.006088 -0.008140 -0.009046
# 2    NaN -0.007098  0.217908 -0.007986 -0.007562 -0.006864 -0.006437
# 3    NaN -0.010160 -0.007986  0.216034 -0.008066 -0.012612 -0.005941
# 4    NaN -0.006088 -0.007562 -0.008066  0.213759 -0.006502 -0.006446
# 5    NaN -0.008140 -0.006864 -0.012612 -0.006502  0.214365 -0.013227
# 6    NaN -0.009046 -0.006437 -0.005941 -0.006446 -0.013227  0.211195
# 7    NaN -0.006554 -0.004378 -0.006732 -0.006088 -0.007059 -0.010787
# 8    NaN -0.002356 -0.005165 -0.006167 -0.009197 -0.005845 -0.008552
# 9    NaN -0.002530 -0.001398 -0.008737 -0.007313 -0.009748 -0.005250
#
# year         7         8         9
# year
# 0          NaN       NaN       NaN
# 1    -0.006554 -0.002356 -0.002530
# 2    -0.004378 -0.005165 -0.001398
# 3    -0.006732 -0.006167 -0.008737
# 4    -0.006088 -0.009197 -0.007313
# 5    -0.007059 -0.005845 -0.009748
# 6    -0.010787 -0.008552 -0.005250
# 7     0.206334 -0.009277 -0.006360
# 8    -0.009277  0.212303 -0.013382
# 9    -0.006360 -0.013382  0.206960
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.818
# Model:                            OLS   Adj. R-squared (uncentered):              0.818
# Method:                 Least Squares   F-statistic:                          4.054e+05
# Date:                Tue, 16 Sep 2025   Prob (F-statistic):                        0.00
# Time:                        16:50:12   Log-Likelihood:                         -55431.
# No. Observations:               90000   AIC:                                  1.109e+05
# Df Residuals:                   89999   BIC:                                  1.109e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# y_lag          0.8982      0.001    636.745      0.000       0.895       0.901
# ==============================================================================
# Omnibus:                        1.413   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.493   Jarque-Bera (JB):                1.417
# Skew:                          -0.003   Prob(JB):                        0.492
# Kurtosis:                       2.982   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
